# %% [markdown]
# Que 1: what is flask framework? what are the advantages of the flask framework.

# %% [markdown]
# Ans: Flask is a high performance , open source web application framework. flask web framework follows the MVT(model-view-Template) architectural pattern or you can say MVC(Model-view-controller) pattern because the controller is handel by the system. flask is fast , lightweight, powerful, simple, and easy to use.

# %% [markdown]
# 1. scalable . size is everything, and flask's status as a microframework means that you can use it to grow a tech project such as a web app incredibly quickly
# 2. Flexible: This is the core feature of Flask,and one of its biggest advantages.To paraphrase one of the principles of the zen of python,simplicity is better than complexity, because it can be easily rearrange and moved around.
# 3.Easy to negotiate: like Django, being able to find your way around easily is key for allowing web developers to concentrate on just coding quickly, without getting bogged down.
# 4. Lightweight: when we use this in relation to a tool or framework
# 5. Documentation: following the creators own theory that "nice documentation design makes you actually write documentation,: flask users will find a healthy number of example and tips arranged in a structured manner.

# %% [markdown]
# Que2: what is app routing in flask? why do we use app routes?

# %% [markdown]
# Ans: App routing means mapping the URLs to a specific function that will handel the logic for that URL. Modern web framework use more meaningful URLs to help users remember the URLs and make navigations simpler. App routing is used to map the specific URL with the associates function that is intended to perform some task. it is used to access some particular page like Flask Tutorial in the web application.

# %% [markdown]
# Que 3. write a simple flask application to display "hello_world" attach the screenshot of the output in jupyter notebook

# %% [markdown]
# ![Screenshot 2023-03-12 120114 new.png](attachment:79aef3a8-32b0-42d9-add7-8c2b6a330626.png)

# %% [markdown]
# Que4 : what functionis used in flask for url building ?

# %%
Ans:The url_for() function is used to build a URL to the specific function dynamically . The first argument isthe name of the specific function, and then we can pass any num of keyword argument correspon
